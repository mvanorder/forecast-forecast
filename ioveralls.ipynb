# %%
''' general use functions and classes '''

class func:
    def __init__(self):
        if type(self) == int:
            return self+1
        else:
            return self

def read_list_from_file(filename):
    """ Read the zip codes list from the csv file.
        
    :param filename: the name of the file
    :type filename: sting
    """
    with open(filename, "r") as z_list:
        return z_list.read().strip().split(',')
    
def key_list(d=dict):
    ''' Write the dict keys to a list and return that list 
    
    :param d: A python dictionary
    :return: A list fo the keys from the python dictionary
    '''
    
    keys = d.keys()
    key_list = []
    for k in keys:
        key_list.append(k)
    return key_list

def all_keys(d):
    ''' Get all the dicitonary and "." format, nested dictionary keys
    from a dict, add them to a list, return the list.
    
    :param d: A python dictionary
    :return: A list of every key in the dictionary
    '''
    keys = []    
    for key, value in d.items():
        if isinstance(d[key], dict):
            for sub_key in all_keys(value):
                keys.append(f'{key}.{sub_key}')
        else:
            keys.append(str(key))
    return keys

def compare_dicts(one, the_other):
    ''' Compare the values of two dicts, key by common key. When the values are
    numbers return the difference, when strings return 0 if the strings are
    equal and 1 if they are different, when dicts run this function, when
    NoneType set the value to None.
    
    *** When there is a key present in one and not the_other the action is to
    print a message and otherwise pass over it.
    ***
    
    :params one, the_other: dictionaries with the same set of keys and sub-keys
    :type one, the_other: dict
    '''
    
    delta = {}  # The delta dict.    
    for (k, v) in one.items():
        try:
            # Check and compare dictionaries according to their value type
            if type(v) == int or type(v) == float:
                if type(the_other[k]) == int or type(the_other[k]) == float:
                    delta[k] = v - the_other[k]
            elif type(v) == dict:
                delta[k] = make_delta(v, the_other[k])
            elif type(v) == str:
                if v == the_other[k]:
                    delta[k] = 0
                else:
                    delta[k] = 1
            elif type(v):
                delta[k] = None
        except KeyError as e:
            print(f'missing key..... {e}')
    return delta

# %%
def iter_dict_values(d, func):
    ### THIS DOES NOT WORK ###
    ''' Iterate over each key-value pair and perform the specified operation on
    it.
    
    :param d: a dictionary
    :param f: a function that can take the values of the dictionary parameter
    :type f: python function
    '''
    
    for key, value in d.items():
        if isinstance(d[key], dict):
            for sub_key in all_keys(value):
                value[sub_key] = func(value[sub_key])
        else:
            temp[key] = func(key[value]) #THE RETURNED VALUE FROM THE TRANSFORM FUNCTION
    return temp

# %%
def flatten(dic, _key=None):
    ''' Take a dictionary and rewrite in 1D with each value having its full
    key path.
    '''
    print(f'entered flatten() with _key, "{_key}".')
    flat_d = {}
    n=0
    for (k, v) in dic.items():
        n+=1
        print(f'first line of iteration {n}.')
        if type(v) == dict:
            _key = f'{_key}.{str(k)}' # Update the _key
            print(f'the variable "_key" has been set to {_key} by flatten().\
            running flatten() again with _key={_key}')
            for sub_key in flatten(v, _key=_key):
                flat_d[f'{_key}.{str(sub_key)})'] = v
        elif not _key:
#             print('_key is an empty string....I am setting it to the dic key.')
            flat_d[f'{_key}.{str(k)})'] = v
#             _key = str(k)
#             print(f'keys update: _key={_key}          str(k)={str(k)}')
            flat_d[f'{_key}.{str(k)})'] = v
    return flat_d

# %%
def all_values(d, values=[]):
    ''' Get all the dicitonary and nested dictionary keys from a dict, add them
    to a list, return the list.
    
    :param d: A python dictionary
    :return: A list of every key in the dictionary
    '''
#     values = []
    for key, value in d.items():
        if isinstance(d[key], dict):
            for sub_value in all_values(d[key], values=values):
#                 all_values(value)
                print(sub_value)
                values.append(d[key])
        else:
            values.append(value)
    return values




dic = {'0': 0,
      '1': 1,
      '10': {'tens': 1,
            'ones': 0
            },
      '111': {'tens': {'tens': 1,
                      'ones': 1
                      },
             'ones': 1}
      }

import pprint
# pprint.pprint(dic)
keys = all_keys(dic)
print(keys)
all_values(dic)
# flatten(dic)
# Out:
# ['0', '1', '10.tens', '10.ones', '111.tens.tens', '111.tens.ones', '111.ones']
# 0
# 1
# 1
# 0
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# ...
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# {'tens': 1, 'ones': 0}
# Traceback (most recent call last):
#   File "/Users/chuckvanhoff/.local/share/virtualenvs/forcast-forcast-Gfjr28rT/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-80d59e323f77>", line 37, in <module>
#     all_values(dic)
#   File "<ipython-input-12-80d59e323f77>", line 13, in all_values
#     print(sub_value)
#   File "/Users/chuckvanhoff/.local/share/virtualenvs/forcast-forcast-Gfjr28rT/lib/python3.7/site-packages/ipykernel/iostream.py", line 402, in write
#     self.pub_thread.schedule(lambda : self._buffer.write(string))
#   File "/Users/chuckvanhoff/.local/share/virtualenvs/forcast-forcast-Gfjr28rT/lib/python3.7/site-packages/ipykernel/iostream.py", line 205, in schedule
#     self._event_pipe.send(b'')
#   File "/Users/chuckvanhoff/.local/share/virtualenvs/forcast-forcast-Gfjr28rT/lib/python3.7/site-packages/zmq/sugar/socket.py", line 400, in send
#     return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#   File "zmq/backend/cython/socket.pyx", line 728, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 775, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 242, in zmq.backend.cython.socket._send_copy
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/chuckvanhoff/.local/share/virtualenvs/forcast-forcast-Gfjr28rT/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2034, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/chuckvanhoff/.local/share/virtualenvs/forcast-forcast-Gfjr28rT/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1151, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/chuckvanhoff/.local/share/virtualenvs/forcast-forcast-Gfjr28rT/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/chuckvanhoff/.local/share/virtualenvs/forcast-forcast-Gfjr28rT/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/chuckvanhoff/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/chuckvanhoff/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/chuckvanhoff/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/chuckvanhoff/anaconda3/lib/python3.7/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/chuckvanhoff/anaconda3/lib/python3.7/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/chuckvanhoff/.local/share/virtualenvs/forcast-forcast-Gfjr28rT/lib/python3.7/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
# class func:
#     def __init__(self)
#         if type(self) == int:
#             return self+1
#         else:
#             return self
d = {'a':1, 'b':2, 'c':3}
print(d)
iter_dict_values(d, func)
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-5a222232a26e> in <module>
#       7 d = {'a':1, 'b':2, 'c':3}
#       8 print(d)
# ----> 9 iter_dict_values(d, func)
#
# <ipython-input-3-1233fcbc22d1> in iter_dict_values(d, func)
#      94                 value[sub_key] = func(value[sub_key])
#      95         else:
# ---> 96             temp[key] = func(key[value]) #THE RETURNED VALUE FROM THE TRANSFORM FUNCTION
#      97     return temp
#
# IndexError: string index out of range
